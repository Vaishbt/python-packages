# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
pwd
# Out:
# 'C:\\Users\\pbhan\\Downloads\\use_cases_EDA_UPDATED\\FitBit'

# %%
activity = pd.read_csv("FitBit data.csv")

# %%
activity
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366    3/25/2016       11004       7.110000         7.110000
# 1    1503960366    3/26/2016       17609      11.550000        11.550000
# 2    1503960366    3/27/2016       12736       8.530000         8.530000
# 3    1503960366    3/28/2016       13231       8.930000         8.930000
# 4    1503960366    3/29/2016       12041       7.850000         7.850000
# ..          ...          ...         ...            ...              ...
# 452  8877689391     4/8/2016       23014      20.389999        20.389999
# 453  8877689391     4/9/2016       16470       8.070000         8.070000
# 454  8877689391    4/10/2016       28497      27.530001        27.530001
# 455  8877689391    4/11/2016       10622       8.060000         8.060000
# 456  8877689391    4/12/2016        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                         0.0                2.57                      0.46
# 1                         0.0                6.92                      0.73
# 2                         0.0                4.66                      0.16
# 3                         0.0                3.19                      0.79
# 4                         0.0                2.16                      1.09
# ..                        ...                 ...                       ...
# 452                       0.0               11.10                      0.63
# 453                       0.0                0.00                      0.02
# 454                       0.0               21.92                      1.12
# 455                       0.0                1.47                      0.15
# 456                       0.0                0.00                      0.00
#
#      LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 0                   4.07                     0.00                 33
# 1                   3.91                     0.00                 89
# 2                   3.71                     0.00                 56
# 3                   4.95                     0.00                 39
# 4                   4.61                     0.00                 28
# ..                   ...                      ...                ...
# 452                 8.62                     0.00                 70
# 453                 8.02                     0.00                 90
# 454                 4.46                     0.00                128
# 455                 6.37                     0.01                 18
# 456                 1.78                     0.00                  0
#
#      FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories
# 0                     12                   205               804      1819
# 1                     17                   274               588      2154
# 2                      5                   268               605      1944
# 3                     20                   224              1080      1932
# 4                     28                   243               763      1886
# ..                   ...                   ...               ...       ...
# 452                   29                   359               982      4196
# 453                    9                   289              1052      3841
# 454                   46                   211              1055      4526
# 455                    7                   225              1190      2820
# 456                    0                    58               531       938
#
# [457 rows x 15 columns]

# %%
activity.head()
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366    3/25/2016       11004           7.11             7.11
# 1  1503960366    3/26/2016       17609          11.55            11.55
# 2  1503960366    3/27/2016       12736           8.53             8.53
# 3  1503960366    3/28/2016       13231           8.93             8.93
# 4  1503960366    3/29/2016       12041           7.85             7.85
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                2.57                      0.46
# 1                       0.0                6.92                      0.73
# 2                       0.0                4.66                      0.16
# 3                       0.0                3.19                      0.79
# 4                       0.0                2.16                      1.09
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 0                 4.07                      0.0                 33
# 1                 3.91                      0.0                 89
# 2                 3.71                      0.0                 56
# 3                 4.95                      0.0                 39
# 4                 4.61                      0.0                 28
#
#    FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories
# 0                   12                   205               804      1819
# 1                   17                   274               588      2154
# 2                    5                   268               605      1944
# 3                   20                   224              1080      1932
# 4                   28                   243               763      1886

# %%
activity.tail()
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 452  8877689391     4/8/2016       23014      20.389999        20.389999
# 453  8877689391     4/9/2016       16470       8.070000         8.070000
# 454  8877689391    4/10/2016       28497      27.530001        27.530001
# 455  8877689391    4/11/2016       10622       8.060000         8.060000
# 456  8877689391    4/12/2016        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 452                       0.0               11.10                      0.63
# 453                       0.0                0.00                      0.02
# 454                       0.0               21.92                      1.12
# 455                       0.0                1.47                      0.15
# 456                       0.0                0.00                      0.00
#
#      LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 452                 8.62                     0.00                 70
# 453                 8.02                     0.00                 90
# 454                 4.46                     0.00                128
# 455                 6.37                     0.01                 18
# 456                 1.78                     0.00                  0
#
#      FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories
# 452                   29                   359               982      4196
# 453                    9                   289              1052      3841
# 454                   46                   211              1055      4526
# 455                    7                   225              1190      2820
# 456                    0                    58               531       938

# %%
activity.describe()
# Out:
#                  Id    TotalSteps  TotalDistance  TrackerDistance  \
# count  4.570000e+02    457.000000     457.000000       457.000000
# mean   4.628595e+09   6546.562363       4.663523         4.609847
# std    2.293781e+09   5398.493064       4.082072         4.068540
# min    1.503960e+09      0.000000       0.000000         0.000000
# 25%    2.347168e+09   1988.000000       1.410000         1.280000
# 50%    4.057193e+09   5986.000000       4.090000         4.090000
# 75%    6.391747e+09  10198.000000       7.160000         7.110000
# max    8.877689e+09  28497.000000      27.530001        27.530001
#
#        LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# count                457.000000          457.000000                457.000000
# mean                   0.179427            1.180897                  0.478643
# std                    0.849232            2.487159                  0.830995
# min                    0.000000            0.000000                  0.000000
# 25%                    0.000000            0.000000                  0.000000
# 50%                    0.000000            0.000000                  0.020000
# 75%                    0.000000            1.310000                  0.670000
# max                    6.727057           21.920000                  6.400000
#
#        LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# count           457.000000               457.000000         457.000000
# mean              2.890197                 0.001904          16.623632
# std               2.237523                 0.008487          28.919704
# min               0.000000                 0.000000           0.000000
# 25%               0.870000                 0.000000           0.000000
# 50%               2.930000                 0.000000           0.000000
# 75%               4.460000                 0.000000          25.000000
# max              12.510000                 0.100000         202.000000
#
#        FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  \
# count           457.000000            457.000000        457.000000
# mean             13.070022            170.070022        995.282276
# std              36.208635            122.205372        337.021404
# min               0.000000              0.000000         32.000000
# 25%               0.000000             64.000000        728.000000
# 50%               1.000000            181.000000       1057.000000
# 75%              16.000000            257.000000       1285.000000
# max             660.000000            720.000000       1440.000000
#
#           Calories
# count   457.000000
# mean   2189.452954
# std     815.484523
# min       0.000000
# 25%    1776.000000
# 50%    2062.000000
# 75%    2667.000000
# max    4562.000000

# %%
activity.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 457 entries, 0 to 456
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Id                        457 non-null    int64
#  1   ActivityDate              457 non-null    object
#  2   TotalSteps                457 non-null    int64
#  3   TotalDistance             457 non-null    float64
#  4   TrackerDistance           457 non-null    float64
#  5   LoggedActivitiesDistance  457 non-null    float64
#  6   VeryActiveDistance        457 non-null    float64
#  7   ModeratelyActiveDistance  457 non-null    float64
#  8   LightActiveDistance       457 non-null    float64
#  9   SedentaryActiveDistance   457 non-null    float64
#  10  VeryActiveMinutes         457 non-null    int64
#  11  FairlyActiveMinutes       457 non-null    int64
#  12  LightlyActiveMinutes      457 non-null    int64
#  13  SedentaryMinutes          457 non-null    int64
#  14  Calories                  457 non-null    int64
# dtypes: float64(7), int64(7), object(1)
# memory usage: 53.7+ KB

# %%
activity.isnull().sum()
# Out:
# Id                          0
# ActivityDate                0
# TotalSteps                  0
# TotalDistance               0
# TrackerDistance             0
# LoggedActivitiesDistance    0
# VeryActiveDistance          0
# ModeratelyActiveDistance    0
# LightActiveDistance         0
# SedentaryActiveDistance     0
# VeryActiveMinutes           0
# FairlyActiveMinutes         0
# LightlyActiveMinutes        0
# SedentaryMinutes            0
# Calories                    0
# dtype: int64

# %%
activity.shape
# Out:
# (457, 15)

# %%
activity1 = activity.copy()

# %%
activity1['ActivityDate'].head(10)
# Out:
# 0    3/25/2016
# 1    3/26/2016
# 2    3/27/2016
# 3    3/28/2016
# 4    3/29/2016
# 5    3/30/2016
# 6    3/31/2016
# 7     4/1/2016
# 8     4/2/2016
# 9     4/3/2016
# Name: ActivityDate, dtype: object

# %%
activity1["ActivityDate"].unique()
# Out:
# array(['3/25/2016', '3/26/2016', '3/27/2016', '3/28/2016', '3/29/2016',
#        '3/30/2016', '3/31/2016', '4/1/2016', '4/2/2016', '4/3/2016',
#        '4/4/2016', '4/5/2016', '4/6/2016', '4/7/2016', '4/8/2016',
#        '4/9/2016', '4/10/2016', '4/11/2016', '4/12/2016', '3/12/2016',
#        '3/13/2016', '3/14/2016', '3/15/2016', '3/16/2016', '3/17/2016',
#        '3/18/2016', '3/19/2016', '3/20/2016', '3/21/2016', '3/22/2016',
#        '3/23/2016', '3/24/2016'], dtype=object)

# %%
activity1['Year']=pd.DatetimeIndex(activity1['ActivityDate']).year
activity1['Month']=pd.DatetimeIndex(activity1['ActivityDate']).month
activity1['Date']=pd.DatetimeIndex(activity1['ActivityDate']).day

# %%
activity1.head()
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366    3/25/2016       11004           7.11             7.11
# 1  1503960366    3/26/2016       17609          11.55            11.55
# 2  1503960366    3/27/2016       12736           8.53             8.53
# 3  1503960366    3/28/2016       13231           8.93             8.93
# 4  1503960366    3/29/2016       12041           7.85             7.85
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                2.57                      0.46
# 1                       0.0                6.92                      0.73
# 2                       0.0                4.66                      0.16
# 3                       0.0                3.19                      0.79
# 4                       0.0                2.16                      1.09
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 0                 4.07                      0.0                 33
# 1                 3.91                      0.0                 89
# 2                 3.71                      0.0                 56
# 3                 4.95                      0.0                 39
# 4                 4.61                      0.0                 28
#
#    FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories  \
# 0                   12                   205               804      1819
# 1                   17                   274               588      2154
# 2                    5                   268               605      1944
# 3                   20                   224              1080      1932
# 4                   28                   243               763      1886
#
#    Year  Month  Date
# 0  2016      3    25
# 1  2016      3    26
# 2  2016      3    27
# 3  2016      3    28
# 4  2016      3    29

# %%
activity1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 457 entries, 0 to 456
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Id                        457 non-null    int64
#  1   ActivityDate              457 non-null    object
#  2   TotalSteps                457 non-null    int64
#  3   TotalDistance             457 non-null    float64
#  4   TrackerDistance           457 non-null    float64
#  5   LoggedActivitiesDistance  457 non-null    float64
#  6   VeryActiveDistance        457 non-null    float64
#  7   ModeratelyActiveDistance  457 non-null    float64
#  8   LightActiveDistance       457 non-null    float64
#  9   SedentaryActiveDistance   457 non-null    float64
#  10  VeryActiveMinutes         457 non-null    int64
#  11  FairlyActiveMinutes       457 non-null    int64
#  12  LightlyActiveMinutes      457 non-null    int64
#  13  SedentaryMinutes          457 non-null    int64
#  14  Calories                  457 non-null    int64
#  15  Year                      457 non-null    int64
#  16  Month                     457 non-null    int64
#  17  Date                      457 non-null    int64
# dtypes: float64(7), int64(10), object(1)
# memory usage: 64.4+ KB

# %%
activity1 = activity1.drop(["TrackerDistance"],axis=1)

# %%
activity1
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  \
# 0    1503960366    3/25/2016       11004       7.110000
# 1    1503960366    3/26/2016       17609      11.550000
# 2    1503960366    3/27/2016       12736       8.530000
# 3    1503960366    3/28/2016       13231       8.930000
# 4    1503960366    3/29/2016       12041       7.850000
# ..          ...          ...         ...            ...
# 452  8877689391     4/8/2016       23014      20.389999
# 453  8877689391     4/9/2016       16470       8.070000
# 454  8877689391    4/10/2016       28497      27.530001
# 455  8877689391    4/11/2016       10622       8.060000
# 456  8877689391    4/12/2016        2350       1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                         0.0                2.57                      0.46
# 1                         0.0                6.92                      0.73
# 2                         0.0                4.66                      0.16
# 3                         0.0                3.19                      0.79
# 4                         0.0                2.16                      1.09
# ..                        ...                 ...                       ...
# 452                       0.0               11.10                      0.63
# 453                       0.0                0.00                      0.02
# 454                       0.0               21.92                      1.12
# 455                       0.0                1.47                      0.15
# 456                       0.0                0.00                      0.00
#
#      LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 0                   4.07                     0.00                 33
# 1                   3.91                     0.00                 89
# 2                   3.71                     0.00                 56
# 3                   4.95                     0.00                 39
# 4                   4.61                     0.00                 28
# ..                   ...                      ...                ...
# 452                 8.62                     0.00                 70
# 453                 8.02                     0.00                 90
# 454                 4.46                     0.00                128
# 455                 6.37                     0.01                 18
# 456                 1.78                     0.00                  0
#
#      FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories  \
# 0                     12                   205               804      1819
# 1                     17                   274               588      2154
# 2                      5                   268               605      1944
# 3                     20                   224              1080      1932
# 4                     28                   243               763      1886
# ..                   ...                   ...               ...       ...
# 452                   29                   359               982      4196
# 453                    9                   289              1052      3841
# 454                   46                   211              1055      4526
# 455                    7                   225              1190      2820
# 456                    0                    58               531       938
#
#      Year  Month  Date
# 0    2016      3    25
# 1    2016      3    26
# 2    2016      3    27
# 3    2016      3    28
# 4    2016      3    29
# ..    ...    ...   ...
# 452  2016      4     8
# 453  2016      4     9
# 454  2016      4    10
# 455  2016      4    11
# 456  2016      4    12
#
# [457 rows x 17 columns]

# %%
activity1.head(20)
# Out:
#             Id ActivityDate  TotalSteps  TotalDistance  \
# 0   1503960366    3/25/2016       11004           7.11
# 1   1503960366    3/26/2016       17609          11.55
# 2   1503960366    3/27/2016       12736           8.53
# 3   1503960366    3/28/2016       13231           8.93
# 4   1503960366    3/29/2016       12041           7.85
# 5   1503960366    3/30/2016       10970           7.16
# 6   1503960366    3/31/2016       12256           7.86
# 7   1503960366     4/1/2016       12262           7.87
# 8   1503960366     4/2/2016       11248           7.25
# 9   1503960366     4/3/2016       10016           6.37
# 10  1503960366     4/4/2016       14557           9.80
# 11  1503960366     4/5/2016       14844           9.73
# 12  1503960366     4/6/2016       11974           7.67
# 13  1503960366     4/7/2016       10198           6.44
# 14  1503960366     4/8/2016       12521           7.94
# 15  1503960366     4/9/2016       12432           8.10
# 16  1503960366    4/10/2016       10057           6.98
# 17  1503960366    4/11/2016       10990           7.26
# 18  1503960366    4/12/2016         224           0.14
# 19  1624580081    3/25/2016        1810           1.18
#
#     LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                        0.0                2.57                      0.46
# 1                        0.0                6.92                      0.73
# 2                        0.0                4.66                      0.16
# 3                        0.0                3.19                      0.79
# 4                        0.0                2.16                      1.09
# 5                        0.0                2.36                      0.51
# 6                        0.0                2.29                      0.49
# 7                        0.0                3.32                      0.83
# 8                        0.0                3.00                      0.45
# 9                        0.0                0.91                      1.28
# 10                       0.0                3.39                      0.70
# 11                       0.0                2.94                      0.76
# 12                       0.0                2.04                      0.48
# 13                       0.0                1.20                      0.79
# 14                       0.0                3.31                      0.90
# 15                       0.0                2.59                      0.59
# 16                       0.0                4.00                      0.49
# 17                       0.0                2.04                      0.57
# 18                       0.0                0.00                      0.00
# 19                       0.0                0.00                      0.00
#
#     LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 0                  4.07                     0.00                 33
# 1                  3.91                     0.00                 89
# 2                  3.71                     0.00                 56
# 3                  4.95                     0.00                 39
# 4                  4.61                     0.00                 28
# 5                  4.29                     0.00                 30
# 6                  5.04                     0.00                 33
# 7                  3.64                     0.00                 47
# 8                  3.74                     0.00                 40
# 9                  4.18                     0.00                 15
# 10                 5.69                     0.00                 43
# 11                 6.04                     0.00                 36
# 12                 5.15                     0.00                 27
# 13                 4.45                     0.00                 17
# 14                 3.74                     0.00                 46
# 15                 4.92                     0.00                 32
# 16                 2.48                     0.00                 44
# 17                 4.65                     0.00                 26
# 18                 0.13                     0.00                  0
# 19                 1.13                     0.01                  0
#
#     FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories  \
# 0                    12                   205               804      1819
# 1                    17                   274               588      2154
# 2                     5                   268               605      1944
# 3                    20                   224              1080      1932
# 4                    28                   243               763      1886
# 5                    13                   223              1174      1820
# 6                    12                   239               820      1889
# 7                    21                   200               866      1868
# 8                    11                   244               636      1843
# 9                    30                   314               655      1850
# 10                   18                   285               757      2030
# 11                   18                   341               736      2083
# 12                   12                   228              1173      1861
# 13                   20                   195              1208      1755
# 14                   22                   212              1160      1895
# 15                   15                   248               738      1883
# 16                   13                   168               737      1755
# 17                   14                   216               855      1811
# 18                    0                     9                32        50
# 19                    0                   121              1319      1373
#
#     Year  Month  Date
# 0   2016      3    25
# 1   2016      3    26
# 2   2016      3    27
# 3   2016      3    28
# 4   2016      3    29
# 5   2016      3    30
# 6   2016      3    31
# 7   2016      4     1
# 8   2016      4     2
# 9   2016      4     3
# 10  2016      4     4
# 11  2016      4     5
# 12  2016      4     6
# 13  2016      4     7
# 14  2016      4     8
# 15  2016      4     9
# 16  2016      4    10
# 17  2016      4    11
# 18  2016      4    12
# 19  2016      3    25

# %%
plt.figure(figsize=(20,10))

ax= sns.boxplot(x='Date',y='Calories', data=activity1)
ax = sns.swarmplot(x='Date', y='Calories', data=activity1, color="grey")
ax.set_title('Box plot of Calories with Jitter bu day of the month')
# Out:
# Text(0.5, 1.0, 'Box plot of Calories with Jitter bu day of the month')

# %%
activity1['Week'] = pd.to_datetime(activity1.ActivityDate).dt.week
activity1['Year'] = pd.to_datetime(activity1.ActivityDate).dt.year
# Out:
# C:\Users\pbhan\AppData\Local\Temp\ipykernel_3716\2340274953.py:1: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   activity1['Week'] = pd.to_datetime(activity1.ActivityDate).dt.week

# %%
activity1.head()
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  \
# 0  1503960366    3/25/2016       11004           7.11
# 1  1503960366    3/26/2016       17609          11.55
# 2  1503960366    3/27/2016       12736           8.53
# 3  1503960366    3/28/2016       13231           8.93
# 4  1503960366    3/29/2016       12041           7.85
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                2.57                      0.46
# 1                       0.0                6.92                      0.73
# 2                       0.0                4.66                      0.16
# 3                       0.0                3.19                      0.79
# 4                       0.0                2.16                      1.09
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 0                 4.07                      0.0                 33
# 1                 3.91                      0.0                 89
# 2                 3.71                      0.0                 56
# 3                 4.95                      0.0                 39
# 4                 4.61                      0.0                 28
#
#    FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories  \
# 0                   12                   205               804      1819
# 1                   17                   274               588      2154
# 2                    5                   268               605      1944
# 3                   20                   224              1080      1932
# 4                   28                   243               763      1886
#
#    Year  Month  Date  Week
# 0  2016      3    25    12
# 1  2016      3    26    12
# 2  2016      3    27    12
# 3  2016      3    28    13
# 4  2016      3    29    13

# %%
type(activity1.ActivityDate)
# Out:
# pandas.core.series.Series

# %%
activity1.ActivityDate.dtype
# Out:
# dtype('O')

# %%
activity1['ActivityDate']=pd.to_datetime(activity1["ActivityDate"])

# %%
activity1['day'] = activity1['ActivityDate'].dt.day_name()

# %%
activity1.head()
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  \
# 0  1503960366   2016-03-25       11004           7.11
# 1  1503960366   2016-03-26       17609          11.55
# 2  1503960366   2016-03-27       12736           8.53
# 3  1503960366   2016-03-28       13231           8.93
# 4  1503960366   2016-03-29       12041           7.85
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                2.57                      0.46
# 1                       0.0                6.92                      0.73
# 2                       0.0                4.66                      0.16
# 3                       0.0                3.19                      0.79
# 4                       0.0                2.16                      1.09
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 0                 4.07                      0.0                 33
# 1                 3.91                      0.0                 89
# 2                 3.71                      0.0                 56
# 3                 4.95                      0.0                 39
# 4                 4.61                      0.0                 28
#
#    FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories  \
# 0                   12                   205               804      1819
# 1                   17                   274               588      2154
# 2                    5                   268               605      1944
# 3                   20                   224              1080      1932
# 4                   28                   243               763      1886
#
#    Year  Month  Date  Week       day
# 0  2016      3    25    12    Friday
# 1  2016      3    26    12  Saturday
# 2  2016      3    27    12    Sunday
# 3  2016      3    28    13    Monday
# 4  2016      3    29    13   Tuesday

# %%
plt.figure(figsize=(15,8))
ax = sns.barplot(x='day',y='Calories',data=activity1)
ax.set_title('Barplot of calories by day of the week')
# Out:
# Text(0.5, 1.0, 'Barplot of calories by day of the week')

# %%
plt.figure(figsize=(15,8))
ax=sns.scatterplot(x='Calories',y='SedentaryMinutes',data=activity1)
ax.set_title('Scatterplot of calories and SedentaryMinutes')
# Out:
# Text(0.5, 1.0, 'Scatterplot of calories and SedentaryMinutes')

# %%
plt.figure(figsize=(15,8))

ax = sns.scatterplot(x='Calories', y='LightlyActiveMinutes', data=activity1)

ax.set_title('Scatterplot of calories and intense_activities')
# Out:
# Text(0.5, 1.0, 'Scatterplot of calories and intense_activities')

# %%
plt.figure(figsize=(15,8))


ax = sns.scatterplot(x='Calories', y='FairlyActiveMinutes', data=activity1)

ax.set_title('Scatterplot of calories vs Fairly Active Minutes')
# Out:
# Text(0.5, 1.0, 'Scatterplot of calories vs Fairly Active Minutes')

# %%
plt.figure(figsize=(15,8))


ax = sns.scatterplot(x='Calories', y='VeryActiveMinutes', data=activity1)

ax.set_title('Scatterplot of calories and intense_activities')
# Out:
# Text(0.5, 1.0, 'Scatterplot of calories and intense_activities')

# %%
activity1.head(10)
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  \
# 0  1503960366   2016-03-25       11004           7.11
# 1  1503960366   2016-03-26       17609          11.55
# 2  1503960366   2016-03-27       12736           8.53
# 3  1503960366   2016-03-28       13231           8.93
# 4  1503960366   2016-03-29       12041           7.85
# 5  1503960366   2016-03-30       10970           7.16
# 6  1503960366   2016-03-31       12256           7.86
# 7  1503960366   2016-04-01       12262           7.87
# 8  1503960366   2016-04-02       11248           7.25
# 9  1503960366   2016-04-03       10016           6.37
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                2.57                      0.46
# 1                       0.0                6.92                      0.73
# 2                       0.0                4.66                      0.16
# 3                       0.0                3.19                      0.79
# 4                       0.0                2.16                      1.09
# 5                       0.0                2.36                      0.51
# 6                       0.0                2.29                      0.49
# 7                       0.0                3.32                      0.83
# 8                       0.0                3.00                      0.45
# 9                       0.0                0.91                      1.28
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 0                 4.07                      0.0                 33
# 1                 3.91                      0.0                 89
# 2                 3.71                      0.0                 56
# 3                 4.95                      0.0                 39
# 4                 4.61                      0.0                 28
# 5                 4.29                      0.0                 30
# 6                 5.04                      0.0                 33
# 7                 3.64                      0.0                 47
# 8                 3.74                      0.0                 40
# 9                 4.18                      0.0                 15
#
#    FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories  \
# 0                   12                   205               804      1819
# 1                   17                   274               588      2154
# 2                    5                   268               605      1944
# 3                   20                   224              1080      1932
# 4                   28                   243               763      1886
# 5                   13                   223              1174      1820
# 6                   12                   239               820      1889
# 7                   21                   200               866      1868
# 8                   11                   244               636      1843
# 9                   30                   314               655      1850
#
#    Year  Month  Date  Week        day
# 0  2016      3    25    12     Friday
# 1  2016      3    26    12   Saturday
# 2  2016      3    27    12     Sunday
# 3  2016      3    28    13     Monday
# 4  2016      3    29    13    Tuesday
# 5  2016      3    30    13  Wednesday
# 6  2016      3    31    13   Thursday
# 7  2016      4     1    13     Friday
# 8  2016      4     2    13   Saturday
# 9  2016      4     3    13     Sunday

# %%
activity1=activity1.drop(['Week','Year'],axis=1)

# %%
activity1.head()
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  \
# 0  1503960366   2016-03-25       11004           7.11
# 1  1503960366   2016-03-26       17609          11.55
# 2  1503960366   2016-03-27       12736           8.53
# 3  1503960366   2016-03-28       13231           8.93
# 4  1503960366   2016-03-29       12041           7.85
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                2.57                      0.46
# 1                       0.0                6.92                      0.73
# 2                       0.0                4.66                      0.16
# 3                       0.0                3.19                      0.79
# 4                       0.0                2.16                      1.09
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 0                 4.07                      0.0                 33
# 1                 3.91                      0.0                 89
# 2                 3.71                      0.0                 56
# 3                 4.95                      0.0                 39
# 4                 4.61                      0.0                 28
#
#    FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories  \
# 0                   12                   205               804      1819
# 1                   17                   274               588      2154
# 2                    5                   268               605      1944
# 3                   20                   224              1080      1932
# 4                   28                   243               763      1886
#
#    Month  Date       day
# 0      3    25    Friday
# 1      3    26  Saturday
# 2      3    27    Sunday
# 3      3    28    Monday
# 4      3    29   Tuesday

# %%
activity1.shape
# Out:
# (457, 17)

# %%
cal_select =['Calories','VeryActiveMinutes','FairlyActiveMinutes','LightlyActiveMinutes','SedentaryMinutes']
wide_df = activity1[cal_select]

# %%
plt.figure(figsize=(15,8))
ax=sns.lineplot(data=wide_df)
ax.set_title('Un-normalize value of calories and different activity bases on activity')
# Out:
# Text(0.5, 1.0, 'Un-normalize value of calories and different activity ')

# %%
plt.figure(figsize=(15,8))
ax=sns.scatterplot(x='Calories',y='TotalDistance',data=activity1)
ax.set_title('Scatterplot of calories and total distance')
# Out:
# Text(0.5, 1.0, 'Scatterplot of calories and total distance')

# %%
plt.figure(figsize=(15,8))
ax=sns.scatterplot(x='Calories',y='LoggedActivitiesDistance',data=activity1)
ax.set_title('Scatterplot of calories and logged activity distance')
# Out:
# Text(0.5, 1.0, 'Scatterplot of calories and logged activity distance')

# %%
plt.figure(figsize=(15,8))
ax=sns.scatterplot(x='Calories',y='VeryActiveDistance',data=activity1)
ax.set_title('Scatterplot of calories and Very Active Distance')
# Out:
# Text(0.5, 1.0, 'Scatterplot of calories and Very Active Distance')

# %%
plt.figure(figsize=(15,10))
ax = sns.scatterplot(x='Calories', y='ModeratelyActiveDistance', data=activity1)

ax.set_title('Scatterplot of calories and Moderately Active Distance')
# Out:
# Text(0.5, 1.0, 'Scatterplot of calories and Moderately Active Distance')

# %%
plt.figure(figsize=(15,8))
ax = sns.scatterplot(x='Calories', y='LightActiveDistance', data=activity1)
ax.set_title('Scatterplot of calories and Light Active Distance')
# Out:
# Text(0.5, 1.0, 'Scatterplot of calories and Light Active Distance')

# %%
rol_select = ['TotalDistance','LoggedActivitiesDistance','VeryActiveDistance','ModeratelyActiveDistance', 'LightActiveDistance']
wide_df1 = activity1[rol_select]

plt.figure(figsize=(15,8))

ax = sns.lineplot(data=wide_df1)

ax.set_title("Un-normalized value of calories and different activities based on distance")
# Out:
# Text(0.5, 1.0, 'Un-normalized value of calories and different activities based on distance')

# %% [markdown]
# #### The EDA here gives us the insight about the relation between the active hours, the distance for which the user has moderate and intense activity and the calories burnt during that period.
